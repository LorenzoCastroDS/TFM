# %% [markdown]
# Este script esta hecho para introducir todos los datasets train y test de los distintos archivos, es un repositorio a partir del cual otros scripts puedan extraer directamente la informacion y no sea necesario copiar todo el pifostio

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# TRAIN

# %%
df_train_1 = pd.read_csv('/home/dsc/Downloads/CMAPSSData/train_FD001.txt', sep=" ", header=None)
df_train_2 = pd.read_csv('/home/dsc/Downloads/CMAPSSData/train_FD002.txt', sep=" ", header=None)
df_train_3 = pd.read_csv('/home/dsc/Downloads/CMAPSSData/train_FD003.txt', sep=" ", header=None)
df_train_4 = pd.read_csv('/home/dsc/Downloads/CMAPSSData/train_FD004.txt', sep=" ", header=None)

# %%
list_df = [df_train_1, df_train_2, df_train_3, df_train_4]

# %%
list_units_1 = 3
operational_list = []
for n in range(1,list_units_1+1):
    operational = "operarional_setting_" + str(n)
    operational_list.append(operational)

list_units_2 = 23
sensor_measurement_list = []
for n in range(1,list_units_2+1):
    sensor = "sensor_measurement_" + str(n)
    sensor_measurement_list.append(sensor)

# %%
new_list = []
for df in list_df:
    
    df.columns = ["ID", "Cycle"] + operational_list + sensor_measurement_list

    df = df.dropna(axis=1)

    max_cycle_dataset_1 = df.groupby(["ID"])["Cycle"].max().reset_index()
    max_cycle_dataset_1 = max_cycle_dataset_1.rename(columns={"Cycle":"Max_cycle"})
    df = df.merge(max_cycle_dataset_1, how="inner", on="ID")
    df["RUL"] = df["Max_cycle"] - df["Cycle"]
    df = df.drop(["Max_cycle"],axis=1)

    #df.drop(columns="operarional_setting_3",axis=1, inplace=True)
    #columns_to_delete = ['sensor_measurement_1', 'sensor_measurement_5', 'sensor_measurement_6', 'sensor_measurement_10',"sensor_measurement_14", 'sensor_measurement_16', 'sensor_measurement_18', 'sensor_measurement_19']
    #df.drop(columns=columns_to_delete, axis=1, inplace=True)
    new_list.append(df)

# %%
df_train_1 = new_list[0]
df_train_2 = new_list[1]
df_train_3 = new_list[2]
df_train_4 = new_list[3]

# %%
df_train_3
# Out:
#         ID  Cycle  operarional_setting_1  operarional_setting_2  \
# 0        1      1                -0.0005                 0.0004
# 1        1      2                 0.0008                -0.0003
# 2        1      3                -0.0014                -0.0002
# 3        1      4                -0.0020                 0.0001
# 4        1      5                 0.0016                 0.0000
# ...    ...    ...                    ...                    ...
# 24715  100    148                -0.0016                -0.0003
# 24716  100    149                 0.0034                -0.0003
# 24717  100    150                -0.0016                 0.0004
# 24718  100    151                -0.0023                 0.0004
# 24719  100    152                 0.0000                 0.0003
#
#        operarional_setting_3  sensor_measurement_1  sensor_measurement_2  \
# 0                      100.0                518.67                642.36
# 1                      100.0                518.67                642.50
# 2                      100.0                518.67                642.18
# 3                      100.0                518.67                642.92
# 4                      100.0                518.67                641.68
# ...                      ...                   ...                   ...
# 24715                  100.0                518.67                643.78
# 24716                  100.0                518.67                643.29
# 24717                  100.0                518.67                643.84
# 24718                  100.0                518.67                643.94
# 24719                  100.0                518.67                643.64
#
#        sensor_measurement_3  sensor_measurement_4  sensor_measurement_5  ...  \
# 0                   1583.23               1396.84                 14.62  ...
# 1                   1584.69               1396.89                 14.62  ...
# 2                   1582.35               1405.61                 14.62  ...
# 3                   1585.61               1392.27                 14.62  ...
# 4                   1588.63               1397.65                 14.62  ...
# ...                     ...                   ...                   ...  ...
# 24715               1596.01               1424.11                 14.62  ...
# 24716               1596.38               1429.14                 14.62  ...
# 24717               1604.53               1431.41                 14.62  ...
# 24718               1597.56               1426.57                 14.62  ...
# 24719               1599.04               1436.06                 14.62  ...
#
#        sensor_measurement_13  sensor_measurement_14  sensor_measurement_15  \
# 0                    2388.01                8145.32                 8.4246
# 1                    2388.03                8152.85                 8.4403
# 2                    2388.00                8150.17                 8.3901
# 3                    2388.08                8146.56                 8.3878
# 4                    2388.03                8147.80                 8.3869
# ...                      ...                    ...                    ...
# 24715                2388.30                8138.08                 8.5036
# 24716                2388.28                8144.36                 8.5174
# 24717                2388.24                8135.95                 8.5223
# 24718                2388.26                8141.24                 8.5148
# 24719                2388.24                8136.98                 8.5150
#
#        sensor_measurement_16  sensor_measurement_17  sensor_measurement_18  \
# 0                       0.03                    391                   2388
# 1                       0.03                    392                   2388
# 2                       0.03                    391                   2388
# 3                       0.03                    392                   2388
# 4                       0.03                    392                   2388
# ...                      ...                    ...                    ...
# 24715                   0.03                    394                   2388
# 24716                   0.03                    395                   2388
# 24717                   0.03                    396                   2388
# 24718                   0.03                    395                   2388
# 24719                   0.03                    396                   2388
#
#        sensor_measurement_19  sensor_measurement_20  sensor_measurement_21  \
# 0                      100.0                  39.11                23.3537
# 1                      100.0                  38.99                23.4491
# 2                      100.0                  38.85                23.3669
# 3                      100.0                  38.96                23.2951
# 4                      100.0                  39.14                23.4583
# ...                      ...                    ...                    ...
# 24715                  100.0                  38.44                22.9631
# 24716                  100.0                  38.50                22.9746
# 24717                  100.0                  38.39                23.0682
# 24718                  100.0                  38.31                23.0753
# 24719                  100.0                  38.56                23.0847
#
#        RUL
# 0      258
# 1      257
# 2      256
# 3      255
# 4      254
# ...    ...
# 24715    4
# 24716    3
# 24717    2
# 24718    1
# 24719    0
#
# [24720 rows x 27 columns]

# %% [markdown]
# TEST

# %%
df_test_1 = pd.read_csv('/home/dsc/Downloads/CMAPSSData/test_FD001.txt', sep=" ", header=None)
df_test_2 = pd.read_csv('/home/dsc/Downloads/CMAPSSData/test_FD002.txt', sep=" ", header=None)
df_test_3 = pd.read_csv('/home/dsc/Downloads/CMAPSSData/test_FD003.txt', sep=" ", header=None)
df_test_4 = pd.read_csv('/home/dsc/Downloads/CMAPSSData/test_FD004.txt', sep=" ", header=None)

# %%
list_df_test = [df_test_1, df_test_2, df_test_3, df_test_4]

# %%
new_list_test = []
for df in list_df_test:
    
    df.columns = ["ID", "Cycle"] + operational_list + sensor_measurement_list
    df = df.dropna(axis=1)

    #df.drop(columns="operarional_setting_3",axis=1, inplace=True)
    #columns_to_delete = ['sensor_measurement_1', 'sensor_measurement_5', 'sensor_measurement_6', 'sensor_measurement_10',"sensor_measurement_14", 'sensor_measurement_16', 'sensor_measurement_18', 'sensor_measurement_19']
    #df.drop(columns=columns_to_delete, axis=1, inplace=True)
    new_list_test.append(df)

# %%
df_test_1 = new_list_test[0]
df_test_2 = new_list_test[1]
df_test_3 = new_list_test[2]
df_test_4 = new_list_test[3]

# %%
df_test_3
# Out:
#         ID  Cycle  operarional_setting_1  operarional_setting_2  \
# 0        1      1                -0.0017                -0.0004
# 1        1      2                 0.0006                -0.0002
# 2        1      3                 0.0014                -0.0003
# 3        1      4                 0.0027                 0.0001
# 4        1      5                -0.0001                 0.0001
# ...    ...    ...                    ...                    ...
# 16591  100    243                 0.0011                -0.0003
# 16592  100    244                -0.0024                 0.0002
# 16593  100    245                -0.0053                 0.0002
# 16594  100    246                -0.0006                 0.0001
# 16595  100    247                 0.0023                 0.0004
#
#        operarional_setting_3  sensor_measurement_1  sensor_measurement_2  \
# 0                      100.0                518.67                641.94
# 1                      100.0                518.67                642.02
# 2                      100.0                518.67                641.68
# 3                      100.0                518.67                642.20
# 4                      100.0                518.67                642.46
# ...                      ...                   ...                   ...
# 16591                  100.0                518.67                643.04
# 16592                  100.0                518.67                642.47
# 16593                  100.0                518.67                642.70
# 16594                  100.0                518.67                642.19
# 16595                  100.0                518.67                643.19
#
#        sensor_measurement_3  sensor_measurement_4  sensor_measurement_5  ...  \
# 0                   1581.93               1396.93                 14.62  ...
# 1                   1584.86               1398.90                 14.62  ...
# 2                   1581.78               1391.92                 14.62  ...
# 3                   1584.53               1395.34                 14.62  ...
# 4                   1589.03               1395.86                 14.62  ...
# ...                     ...                   ...                   ...  ...
# 16591               1594.99               1411.28                 14.62  ...
# 16592               1591.27               1417.64                 14.62  ...
# 16593               1593.81               1412.70                 14.62  ...
# 16594               1595.63               1406.58                 14.62  ...
# 16595               1592.54               1407.20                 14.62  ...
#
#        sensor_measurement_12  sensor_measurement_13  sensor_measurement_14  \
# 0                     521.89                2387.94                8133.48
# 1                     521.85                2388.01                8137.44
# 2                     522.10                2387.94                8138.25
# 3                     522.45                2387.96                8137.07
# 4                     521.91                2387.97                8134.20
# ...                      ...                    ...                    ...
# 16591                 529.23                2388.24                8162.24
# 16592                 529.27                2388.26                8163.24
# 16593                 529.48                2388.28                8162.12
# 16594                 529.39                2388.33                8164.20
# 16595                 529.59                2388.29                8169.24
#
#        sensor_measurement_15  sensor_measurement_16  sensor_measurement_17  \
# 0                     8.3760                   0.03                    391
# 1                     8.4062                   0.03                    391
# 2                     8.3553                   0.03                    391
# 3                     8.3709                   0.03                    392
# 4                     8.4146                   0.03                    391
# ...                      ...                    ...                    ...
# 16591                 8.2939                   0.03                    395
# 16592                 8.3247                   0.03                    394
# 16593                 8.3264                   0.03                    394
# 16594                 8.2908                   0.03                    395
# 16595                 8.3191                   0.03                    392
#
#        sensor_measurement_18  sensor_measurement_19  sensor_measurement_20  \
# 0                       2388                  100.0                  39.07
# 1                       2388                  100.0                  39.04
# 2                       2388                  100.0                  39.10
# 3                       2388                  100.0                  38.97
# 4                       2388                  100.0                  39.09
# ...                      ...                    ...                    ...
# 16591                   2388                  100.0                  39.40
# 16592                   2388                  100.0                  39.42
# 16593                   2388                  100.0                  39.43
# 16594                   2388                  100.0                  39.40
# 16595                   2388                  100.0                  39.41
#
#        sensor_measurement_21
# 0                    23.4468
# 1                    23.4807
# 2                    23.4244
# 3                    23.4782
# 4                    23.3950
# ...                      ...
# 16591                23.4949
# 16592                23.6011
# 16593                23.5482
# 16594                23.6687
# 16595                23.6536
#
# [16596 rows x 26 columns]

# %% [markdown]
# RUL

# %%
df_RUL_1 = pd.read_csv('/home/dsc/Downloads/CMAPSSData/RUL_FD001.txt', sep=" ", header=None)
df_RUL_2 = pd.read_csv('/home/dsc/Downloads/CMAPSSData/RUL_FD002.txt', sep=" ", header=None)
df_RUL_3 = pd.read_csv('/home/dsc/Downloads/CMAPSSData/RUL_FD003.txt', sep=" ", header=None)
df_RUL_4 = pd.read_csv('/home/dsc/Downloads/CMAPSSData/RUL_FD004.txt', sep=" ", header=None)

# %%
list_df_rul = [df_RUL_1, df_RUL_2, df_RUL_3, df_RUL_4]

# %%
new_list_rul = []
for df in list_df_rul:
    df.dropna(axis=1,inplace=True)
    df.columns = ["RUL"]
    new_list_rul.append(df)

# %%
df_RUL_1 = new_list_rul[0]
df_RUL_2 = new_list_rul[1]
df_RUL_3 = new_list_rul[2]
df_RUL_4 = new_list_rul[3]

# %%
df_RUL_4
# Out:
#      RUL
# 0     22
# 1     39
# 2    107
# 3     75
# 4    149
# ..   ...
# 243   35
# 244  131
# 245  194
# 246  112
# 247   26
#
# [248 rows x 1 columns]

# %% [markdown]
# #### Store the datasets

# %%
# %store df_train_1
# %store df_train_2
# %store df_train_3
# %store df_train_4

# %store df_test_1
# %store df_test_2
# %store df_test_3
# %store df_test_4

# %store df_RUL_1
# %store df_RUL_2
# %store df_RUL_3
# %store df_RUL_4
# Out:
# Stored 'df_train_1' (DataFrame)
# Stored 'df_train_2' (DataFrame)
# Stored 'df_train_3' (DataFrame)
# Stored 'df_train_4' (DataFrame)
# Stored 'df_test_1' (DataFrame)
# Stored 'df_test_2' (DataFrame)
# Stored 'df_test_3' (DataFrame)
# Stored 'df_test_4' (DataFrame)
# Stored 'df_RUL_1' (DataFrame)
# Stored 'df_RUL_2' (DataFrame)
# Stored 'df_RUL_3' (DataFrame)
# Stored 'df_RUL_4' (DataFrame)

# %% [markdown]
# Merge SVR

# %%
nrows2 = df_train_2[df_train_2["ID"]==260].shape[0]
df_train_2.drop(df_train_2.tail(nrows2).index,inplace=True)
nrows4 = df_train_4[df_train_4["ID"]==249].shape[0]
df_train_4.drop(df_train_4.tail(nrows4).index,inplace=True)

# %%
l1 = len(df_train_1["ID"].unique())
l2 = len(df_train_2["ID"].unique())
l3 = len(df_train_3["ID"].unique())

# %%
df_train_2["ID"] = df_train_2["ID"] + l1
df_train_3["ID"] = df_train_3["ID"] + l1 + l2
df_train_4["ID"] = df_train_4["ID"] + l1 + l2 + l3

l1t = len(df_test_1["ID"].unique())
l2t = len(df_test_2["ID"].unique())
l3t = len(df_test_3["ID"].unique())

df_test_2["ID"] = df_test_2["ID"] + l1t
df_test_3["ID"] = df_test_3["ID"] + l1t + l2t
df_test_4["ID"] = df_test_4["ID"] + l1t + l2t + l3t
# Out:
# <ipython-input-20-bdff248d3627>:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test_2["ID"] = df_test_2["ID"] + l1t
# <ipython-input-20-bdff248d3627>:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test_3["ID"] = df_test_3["ID"] + l1t + l2t
# <ipython-input-20-bdff248d3627>:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_test_4["ID"] = df_test_4["ID"] + l1t + l2t + l3t

# %%
df_trains = pd.concat([df_train_1, df_train_2, df_train_3, df_train_4])
df_tests = pd.concat([df_test_1, df_test_2, df_test_3, df_test_4])
df_ruls = pd.concat([df_RUL_1, df_RUL_2, df_RUL_3, df_RUL_4])

# %%
labels_to_drop = ["ID","Cycle"]
X_train = df_trains.drop(labels_to_drop+["RUL"], axis=1)
y_train = df_trains["RUL"]

X_test = df_tests.groupby("ID").last().reset_index().drop(labels_to_drop, axis=1)
y_test = df_ruls
print("X_train columns: ", X_train.columns, "\n",
     "X_test columns: ", X_test.columns, "\n",
     y_train.shape)
# Out:
# X_train columns:  Index(['operarional_setting_1', 'operarional_setting_2',
#        'sensor_measurement_2', 'sensor_measurement_3', 'sensor_measurement_4',
#        'sensor_measurement_7', 'sensor_measurement_8', 'sensor_measurement_9',
#        'sensor_measurement_11', 'sensor_measurement_12',
#        'sensor_measurement_13', 'sensor_measurement_15',
#        'sensor_measurement_17', 'sensor_measurement_20',
#        'sensor_measurement_21'],
#       dtype='object')
#  X_test columns:  Index(['operarional_setting_1', 'operarional_setting_2',
#        'sensor_measurement_2', 'sensor_measurement_3', 'sensor_measurement_4',
#        'sensor_measurement_7', 'sensor_measurement_8', 'sensor_measurement_9',
#        'sensor_measurement_11', 'sensor_measurement_12',
#        'sensor_measurement_13', 'sensor_measurement_15',
#        'sensor_measurement_17', 'sensor_measurement_20',
#        'sensor_measurement_21'],
#       dtype='object')
#  (159788,)
